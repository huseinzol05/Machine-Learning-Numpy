# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
sns.set()

# %%
tesla = pd.read_csv('TSLA.csv')
tesla.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2017-09-05  353.799988  355.489990  345.890015  349.589996  349.589996
# 1  2017-09-06  349.500000  350.980011  341.559998  344.529999  344.529999
# 2  2017-09-07  345.980011  352.480011  343.450012  350.609985  350.609985
# 3  2017-09-08  348.989990  349.779999  342.299988  343.399994  343.399994
# 4  2017-09-11  351.350006  363.709991  350.000000  363.690002  363.690002
#
#     Volume
# 0  3835100
# 1  4091400
# 2  4239200
# 3  3263500
# 4  7667100

# %%
plt.plot(tesla.Close)
plt.show()

# %%
signal = np.copy(tesla.Close.values)

# %%
def anchor(signal, weight):
    buffer = []
    last = signal[0]
    for i in signal:
        smoothed_val = last * weight + (1 - weight) * i
        buffer.append(smoothed_val)
        last = smoothed_val
    return buffer

# %%
anchored = anchor(signal, 0.8)

# %%
plt.plot(np.arange(len(tesla.Close)), tesla.Close)
plt.plot(np.arange(len(tesla.Close)), anchored)
plt.show()
