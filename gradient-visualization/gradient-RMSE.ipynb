# %%
import matplotlib.pyplot as plt
from rmse_plot import *
import numpy as np

'''
subplot_evolution_strategies(step, learning_rate, sigma, population_size,
                                 x_boundary = 1, y_boundary = 2, 
                                 step_x = 20, step_y = 50, midpoint = 0, ax=None)
                                 
step = iteration going down
learning_rate = how much we want population learn
sigma = how much we want to disturb the population
population_size = size of population
'''

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15,5))
ax = subplot_evolution_strategies(8, 0.01, 0.1, 50, ax=ax)
plt.show()

# %%
'''
def subplot_gradient_descent(step, learning_rate, technique, 
                             x_boundary = 1, y_boundary = 2,
                             momentum = 0.9, rho = 0.9, epsilon = 1e-8, 
                             b1 = 0.9, b2 = 0.999,
                             step_x = 20, step_y = 50, midpoint = 0, ax=None)
                                 
step = iteration going down
technique = {'gradient descent', 'momentum', 'nesterov', 'adagrad','rmsprop','adam'}
learning_rate = how much we want population learn
'''

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15,5))
ax = subplot_gradient_descent(8, 0.01, 'gradient descent', ax=ax)
plt.show()

# %%
fig, ax = plt.subplots(nrows=7, ncols=1, figsize=(15,75))
ax[0] = subplot_evolution_strategies(8, 0.01, 0.1, 50, ax=ax[0])
ax[1] = subplot_gradient_descent(8, 0.01, 'gradient descent', ax=ax[1])
ax[2] = subplot_gradient_descent(8, 0.01, 'momentum', ax=ax[2])
ax[3] = subplot_gradient_descent(8, 0.01, 'nesterov', ax=ax[3])
ax[4] = subplot_gradient_descent(8, 0.01, 'adagrad', ax=ax[4])
ax[5] = subplot_gradient_descent(8, 0.01, 'rmsprop', ax=ax[5])
ax[6] = subplot_gradient_descent(8, 0.01, 'adam', ax=ax[6])
plt.show()
